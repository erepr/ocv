# %%
import tkinter as tk
from PIL import Image,ImageTk

root = tk.Tk()
root.title('Map')

def add_it():
    my_image = Image.open("mumbai-full-map.png")
    text_font = ImageFont.truetype("Arial", 46)
    text_to_add = my_entry.get()
    
    edit_image = ImageDraw.Draw(my_image)
    edit_image.text((150, 300), text_to_add, ("red"), font=text_font)
    
    my_image.save("sample.png")
    
    my_entry.delete(0, END)
    my_entry.insert(0, "Saving File...")
    
    my_label.after(2000, show_pic)

def show_pic():
    aspen2 = PhotoImage(file="mumbai-full-map.png")
    my_label.config(image=aspen2)
    
    my_entry.delete(0, END)

aspen = tk.PhotoImage(file="mumbai-full-map.png")

my_label = tk.Label(root, image=aspen)
my_label.pack(pady=20)

my_entry = tk.Entry(root, font=("Helvetica", 24))
my_entry.pack(pady=20)

my_button = tk.Button(root, text="Add Text to Image", command=add_it, font=("Helvetica", 24))
my_button.pack(pady=20)

root.mainloop()

# %%
from tkinter import *
import tkinter as tk
from PIL import Image,ImageTk
from tkinter.ttk import *

ws = tk.Tk()
ws.attributes('-fullscreen', True)
ws.title('PythonGuides')
ws.config(bg='yellow')

img = PhotoImage(file="mumbai-full-map.png")
label = Label(
    ws,
    image=img
)
label.pack()

label = Label.place(x=0,y=0, self)

label = Label(
    ws,
    text = "Fact of the Day"
)
label.place(x=1, y=1)

ws.mainloop()
# Out:
#   File "C:\Users\Akshay\AppData\Local\Temp/ipykernel_2688/2254992823.py", line 18
#     label = Label.place(x=0,y=0, self)
#                                      ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ##### Image Refresh working 100%

# %%
#Import the required library
from tkinter import *
from PIL import Image, ImageTk

#Create an instance of tkinter frame
win = Tk()

#Define geometry of the window
win.geometry("750x600")
win.title("Gallery")

#Define a Function to change to Image
def change_img():
   img2=ImageTk.PhotoImage(Image.open("mumbai-full-map.png"))
   label.configure(image=img2)
   label.image=img2

#Convert To PhotoImage
img1= ImageTk.PhotoImage(Image.open("circle.png"))

#Create a Label widget
label= Label(win,image= img1)
label.pack()

#Create a Button to handle the update Image event
button= Button(win, text = "Change", font = ('Helvetica 13 bold'), command= change_img)
button.pack(pady=15)
win.bind("<Return>", change_img)
win.mainloop()

# %% [markdown]
# ##### Image Refresh working 100%

# %%
from tkinter import *
from tkinter import ttk
from PIL import Image, ImageTk

win = Tk()

win.geometry("750x400")

def update_image():
   canvas.itemconfig(image_container,image=img2)

canvas= Canvas(win, width=650, height= 350)
canvas.pack()

button= ttk.Button(win, text="Update",
command=lambda:update_image())
button.pack()

img1= PhotoImage(file="mumbai-full-map.png")
img2= PhotoImage(file="circle.png")

image_container =canvas.create_image(0,0, anchor="nw",image=img1)
win.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7700/695623713.py in <module>
#      20 img2= PhotoImage(file="circle.png")
#      21
# ---> 22 image_container =canvas.create_image(0,0, anchor="nw",image=img1)
#      23 win.mainloop()
#
# ~\anaconda3\lib\tkinter\__init__.py in create_image(self, *args, **kw)
#    2788     def create_image(self, *args, **kw):
#    2789         """Create image item with coordinates x1,y1."""
# -> 2790         return self._create('image', args, kw)
#    2791
#    2792     def create_line(self, *args, **kw):
#
# ~\anaconda3\lib\tkinter\__init__.py in _create(self, itemType, args, kw)
#    2774         else:
#    2775             cnf = {}
# -> 2776         return self.tk.getint(self.tk.call(
#    2777             self._w, 'create', itemType,
#    2778             *(args + self._options(cnf, kw))))
#
# ...

# %% [markdown]
# #### Main.py

# %%
import tkinter
from tkinter import *
from PIL import Image, ImageTk
import random
import cv2


def locate(map):
    x = random.randint(0, 568)
    y = random.randint(0, 880)
    img = Image.open("circle.png")
    background = Image.open(map)
    new = background.paste(img, (x, y), img)
    background.save('temp.png',"PNG")

def blimp():
    locate("mumbai-full-map.png")
    locate("temp.png")
    locate("temp.png")
 
def update_image():
    global tkimg1
    blimp()
    tkimg1 = ImageTk.PhotoImage(Image.open('temp.png').resize((568, 880)))
    label.config(image = tkimg1)
    label.after(2500, update_image)
 
w = tkinter.Tk()
w.attributes('-fullscreen', True)
im = Image.open('mumbai-full-map.png')
resize_image = im.resize((568, 880))
tkimg1 = ImageTk.PhotoImage(resize_image)
label =  tkinter.Label(w, image=tkimg1)
label.pack()
w.after(2000, update_image)




app = Frame(w, bg="white")
app.grid()
# Create a label in the frame
lmain = Label(app)
lmain.pack()

# Capture from camera
cap = cv2.VideoCapture("rtsp://192.168.1.106:554/user=admin&password=admin@1234&channel=1&stream=0.sdp")

# function for video streaming
def video_stream():
    _, frame = cap.read()
    cv2image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGBA)
    img = Image.fromarray(cv2image)
    imgtk = ImageTk.PhotoImage(image=img)
    lmain.imgtk = imgtk
    lmain.configure(image=imgtk)
    lmain.after(1, video_stream) 

# Create a label in the frame
video_stream()
w.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8560/2605637848.py in <module>
#      31 resize_image = im.resize((568, 880))
#      32 tkimg1 = ImageTk.PhotoImage(resize_image)
# ---> 33 label =  tkinter.Label(w, image=tkimg1)
#      34 label.pack()
#      35 w.after(2000, update_image)
#
# ~\anaconda3\lib\tkinter\__init__.py in __init__(self, master, cnf, **kw)
#    3146
#    3147         """
# -> 3148         Widget.__init__(self, master, 'label', cnf, kw)
#    3149
#    3150
#
# ~\anaconda3\lib\tkinter\__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2570         for k, v in classes:
#    2571             del cnf[k]
# -> 2572         self.tk.call(
#    2573             (widgetName, self._w) + extra + self._options(cnf))
#    2574         for k, v in classes:
#
# TclError: image "pyimage562" doesn't exist

# %%
from tkinter import *
from PIL import ImageTk, Image
import cv2


root = Tk()
# Create a frame
app = Frame(root, bg="white")
app.grid()
# Create a label in the frame
lmain = Label(app)
lmain.grid()

# Capture from camera
cap = cv2.VideoCapture("rtsp://192.168.1.106:554/user=admin&password=admin@1234&channel=1&stream=0.sdp")

# function for video streaming
def video_stream():
    _, frame = cap.read()
    cv2image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGBA)
    img = Image.fromarray(cv2image)
    imgtk = ImageTk.PhotoImage(image=img)
    lmain.imgtk = imgtk
    lmain.configure(image=imgtk)
    lmain.after(1, video_stream) 

video_stream()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8560/2009421243.py in <module>
#      25     lmain.after(1, video_stream)
#      26
# ---> 27 video_stream()
#      28 root.mainloop()
#
# ~\AppData\Local\Temp/ipykernel_8560/2009421243.py in video_stream()
#      22     imgtk = ImageTk.PhotoImage(image=img)
#      23     lmain.imgtk = imgtk
# ---> 24     lmain.configure(image=imgtk)
#      25     lmain.after(1, video_stream)
#      26
#
# ~\anaconda3\lib\tkinter\__init__.py in configure(self, cnf, **kw)
#    1644         the allowed keyword arguments call the method keys.
#    1645         """
# -> 1646         return self._configure('configure', cnf, kw)
#    1647
#    1648     config = configure
#
# ~\anaconda3\lib\tkinter\__init__.py in _configure(self, cmd, cnf, kw)
#    1634         if isinstance(cnf, str):
# ...

# %%
from tkinter import *
root = Tk()
btn_column = Button(root, text="I'm in column 3")
btn_column.grid(column=3)

btn_columnspan = Button(root, text="I have a columnspan of 3")
btn_columnspan.grid(columnspan=3)
root.mainloop()

# %% [markdown]
# ##### Image Overlay

# %%
from tkinter import *
import tkinter as tk
from PIL import Image,ImageTk

import numpy as np

root = tk.Tk()

# Create Image
img = Image.open("circle.png")

background = Image.open("mumbai-full-map.png")

new = background.paste(img, (100, 100), img)
background.save('NewImg.png',"PNG")

NewImg = Image.open("NewImg.png").resize((568, 880))

# Use Image
tkimage = ImageTk.PhotoImage(NewImg)

panel1 = Label(root, image=tkimage)
panel1.grid(row=0, column=2, sticky=E)
root.mainloop()  # Start the GUI
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11340/1312592415.py in <module>
#      20 tkimage = ImageTk.PhotoImage(NewImg)
#      21
# ---> 22 panel1 = Label(root, image=tkimage)
#      23 panel1.grid(row=0, column=2, sticky=E)
#      24 root.mainloop()  # Start the GUI
#
# ~\anaconda3\lib\tkinter\__init__.py in __init__(self, master, cnf, **kw)
#    3146
#    3147         """
# -> 3148         Widget.__init__(self, master, 'label', cnf, kw)
#    3149
#    3150
#
# ~\anaconda3\lib\tkinter\__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2570         for k, v in classes:
#    2571             del cnf[k]
# -> 2572         self.tk.call(
#    2573             (widgetName, self._w) + extra + self._options(cnf))
#    2574         for k, v in classes:
#
# TclError: image "pyimage6" doesn't exist

# %%
from tkinter import *
from tkinter import ttk

root = Tk()

content = ttk.Frame(root)
frame = ttk.Frame(content, borderwidth=5, relief="sunken", width=200, height=100)
namelbl = ttk.Label(content, text="Name")
name = ttk.Entry(content)

onevar = BooleanVar()
twovar = BooleanVar()
threevar = BooleanVar()
onevar.set(True)
twovar.set(False)
threevar.set(True)

one = ttk.Checkbutton(content, text="One", variable=onevar, onvalue=True)
two = ttk.Checkbutton(content, text="Two", variable=twovar, onvalue=True)
three = ttk.Checkbutton(content, text="Three", variable=threevar, onvalue=True)
ok = ttk.Button(content, text="Okay")
cancel = ttk.Button(content, text="Cancel")

content.grid(column=0, row=0)
frame.grid(column=0, row=0, columnspan=3, rowspan=2)
namelbl.grid(column=3, row=0, columnspan=2)
name.grid(column=3, row=1, columnspan=2)
one.grid(column=0, row=3)
two.grid(column=1, row=3)
three.grid(column=2, row=3)
ok.grid(column=3, row=3)
cancel.grid(column=4, row=3)

root.mainloop()

# %%
# import tkinter module
from tkinter import * 
from tkinter.ttk import *
  
# creating main tkinter window/toplevel
master = Tk()
  
# this wil create a label widget
l1 = Label(master, text = "First:")
l2 = Label(master, text = "Second:")
  
# grid method to arrange labels in respective
# rows and columns as specified
l1.grid(row = 0, column = 0, sticky = W, pady = 2)
l2.grid(row = 1, column = 0, sticky = W, pady = 2)
  
# entry widgets, used to take entry from user
e1 = Entry(master)
e2 = Entry(master)
  
# this will arrange entry widgets
e1.grid(row = 0, column = 1, pady = 2)
e2.grid(row = 1, column = 1, pady = 2)
  
# infinite loop which can be terminated by keyboard
# or mouse interrupt
mainloop()

# %%
import tkinter as tk 

import cv2  
from PIL import Image
from PIL import ImageTk
import threading
import os

class MainWindow():
    def __init__(self, window, cap):
        self.window = window
        self.cap = cap
        self.width = self.cap.get(cv2.CAP_PROP_FRAME_WIDTH)
        self.height = self.cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
        self.interval = 10 # Interval in ms to get the latest frame
        # Create canvas for image
        self.canvas = tk.Canvas(self.window, width=600, height=400)
        self.canvas.grid(row=0, column=0)
        # Update image on canvas
        root.after(self.interval, self.update_image)
        self.button = tk.Button()

    def update_image(self):    
        # Get the latest frame and convert image format
        self.OGimage = cv2.cvtColor(self.cap.read()[1], cv2.COLOR_BGR2RGB) # to RGB
        self.OGimage = Image.fromarray(self.OGimage) # to PIL format
        self.image = self.OGimage.resize((600, 400), Image.ANTIALIAS)
        self.image = ImageTk.PhotoImage(self.image) # to ImageTk format
        # Update image
        self.canvas.create_image(0, 0, anchor=tk.NW, image=self.image)
        # Repeat every 'interval' ms
        self.window.after(self.interval, self.update_image)

#def run_decoding(): 
    #os.system("ffmpeg -i rtsp://192.168.1.10?tcp -codec copy -f mpegts udp://127.0.0.1:5000 &")


if __name__ == "__main__":
    #my_cam = ONVIFCamera('192.168.1.10', 80, 'gemer.daniel@gmail.com', 'dg24111998')
    #media = my_cam.create_media_service()
    #ptz = my_cam.create_ptz_service()
    #media_profile = media.GetProfiles()[0]

    # Get PTZ configuration options for getting continuous move range
    #request = ptz.create_type('GetConfigurationOptions')
    #request.ConfigurationToken = media_profile.token
    #ptz_configuration_options = ptz.GetConfigurationOptions(request)

    #request = ptz.create_type('ContinuousMove')
    #request.ProfileToken = media_profile._token

    #ptz.Stop({'ProfileToken': media_profile._token})
    #p1 = threading.Thread(target=run_decoding)
    #p1.start()
    root = tk.Tk()
    MainWindow(root, cv2.VideoCapture("rtsp://192.168.1.106:554/user=admin&password=admin@1234&channel=1&stream=0.sdp"))
    root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Akshay\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Akshay\anaconda3\lib\tkinter\__init__.py", line 814, in callit
#     func(*args)
#   File "C:\Users\Akshay\AppData\Local\Temp/ipykernel_13248/1654229963.py", line 30, in update_image
#     self.canvas.create_image(0, 0, anchor=tk.NW, image=self.image)
#   File "C:\Users\Akshay\anaconda3\lib\tkinter\__init__.py", line 2790, in create_image
#     return self._create('image', args, kw)
#   File "C:\Users\Akshay\anaconda3\lib\tkinter\__init__.py", line 2776, in _create
#     return self.tk.getint(self.tk.call(
# _tkinter.TclError: image "pyimage108" doesn't exist
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13248/1654229963.py in <module>
# ...

# %%
import sys
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
from PyQt5.QtCore import *
import cv2

class MainWindow(QWidget):
    def __init__(self):
        super(MainWindow, self).__init__()

        self.VBL = QVBoxLayout()

        self.FeedLabel = QLabel()
        self.VBL.addWidget(self.FeedLabel)

        self.CancelBTN = QPushButton("Cancel")
        self.CancelBTN.clicked.connect(self.CancelFeed)
        self.VBL.addWidget(self.CancelBTN)

        self.Worker1 = Worker1()

        self.Worker1.start()
        self.Worker1.ImageUpdate.connect(self.ImageUpdateSlot)
        self.setLayout(self.VBL)

    def ImageUpdateSlot(self, Image):
        self.FeedLabel.setPixmap(QPixmap.fromImage(Image))

    def CancelFeed(self):
        self.Worker1.stop()

class Worker1(QThread):
    ImageUpdate = pyqtSignal(QImage)
    def run(self):
        self.ThreadActive = True
        Capture = cv2.VideoCapture("rtsp://192.168.1.106:554/user=admin&password=admin@1234&channel=1&stream=0.sdp")
        while self.ThreadActive:
            ret, frame = Capture.read()
            if ret:
                Image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                FlippedImage = cv2.flip(Image, 1)
                ConvertToQtFormat = QImage(FlippedImage.data, FlippedImage.shape[1], FlippedImage.shape[0], QImage.Format_RGB888)
                Pic = ConvertToQtFormat.scaled(640, 480, Qt.KeepAspectRatio)
                self.ImageUpdate.emit(Pic)
    def stop(self):
        self.ThreadActive = False
        self.quit()

if __name__ == "__main__":
    App = QApplication(sys.argv)
    Root = MainWindow()
    Root.show()
    sys.exit(App.exec())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Akshay\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(800, 600)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.photo = QtWidgets.QLabel(self.centralwidget)
        self.photo.setGeometry(QtCore.QRect(0, 0, 841, 511))
        self.photo.setText("")
        self.photo.setPixmap(QtGui.QPixmap("cat.jpg"))
        self.photo.setScaledContents(True)
        self.photo.setObjectName("photo")
        self.cat = QtWidgets.QPushButton(self.centralwidget)
        self.cat.setGeometry(QtCore.QRect(0, 510, 411, 41))
        self.cat.setObjectName("cat")
        self.dog = QtWidgets.QPushButton(self.centralwidget)
        self.dog.setGeometry(QtCore.QRect(410, 510, 391, 41))
        self.dog.setObjectName("dog")
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 800, 21))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

        self.dog.clicked.connect(self.show_dog)
        self.cat.clicked.connect(self.show_cat)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.cat.setText(_translate("MainWindow", "CAT"))
        self.dog.setText(_translate("MainWindow", "DOG"))

    def show_dog(self):
        self.photo.setPixmap(QtGui.QPixmap("mumbai-full-map.png"))

    def show_cat(self):
        self.photo.setPixmap(QtGui.QPixmap("circle.png"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
